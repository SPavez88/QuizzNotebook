# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sebastian  Pavez**
#
# Currently jobless but hoping to find a data analysis position in the near future

# %% [markdown]
# *I found myself interested in the data analysis field because is an area that will shape future decisions around the world and I would like to be part of that. On top of this, my personal interests of solving problems and finding solutions and patterns motivates me to hopefully follow a career along Data Science*

# %% [markdown]
# ### It ask the user for his or her name and returns a greeting

# %%
your_name = input("Hello there! What's your name? ")
print("Nice to meet you "+your_name+". It is a nice name!")

# %% [markdown]
# This is what I like to do on my spare time:
# * Running
# * Eating pizza
# * Travel!
#
# ****
#
# Like this
# ![running.jpg](attachment:running.jpg "Me running like a pizza")
